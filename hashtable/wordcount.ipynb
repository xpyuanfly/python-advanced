# %%
f = open("1.txt",mode = "r", encoding = 'utf-8' )
lines = f.readlines()
dic_word = {}
for line in lines:
    for word in line:
        dic_word[word] = dic_word.get(word,0) + 1
# dic_word.get(word,0) 
# return dic_word[word] else return 0
# dict 主要用来查表，重复性的次数 词频 频次; 去重 (set)
dic_word
# Out:
# {'i': 9,
#  'n': 18,
#  't': 17,
#  'e': 19,
#  'r': 9,
#  '表': 1,
#  '示': 1,
#  '的': 33,
#  '意': 1,
#  '思': 1,
#  '是': 9,
#  '互': 2,
#  '联': 3,
#  '网': 22,
#  '，': 24,
#  '又': 1,
#  '称': 1,
#  '际': 1,
#  '络': 9,
#  '根': 1,
#  '据': 1,
#  '音': 1,
#  '译': 1,
#  '也': 2,
#  '被': 3,
#  '叫': 1,
#  '做': 1,
#  '因': 2,
#  '特': 3,
#  '(': 1,
#  'I': 4,
#  ')': 1,
#  '、': 9,
#  '英': 1,
#  '与': 3,
#  '之': 2,
#  '间': 3,
#  '所': 2,
#  '串': 1,
#  '连': 7,
#  '成': 2,
#  '庞': 1,
#  '大': 9,
#  '。': 14,
#  '这': 3,
#  '些': 2,
#  '以': 2,
#  '一': 5,
#  '组': 1,
#  '通': 3,
#  '用': 5,
#  '协': 4,
#  '议': 2,
#  '相': 2,
#  '形': 1,
#  '逻': 1,
#  '辑': 1,
#  '上': 2,
#  '单': 1,
#  '且': 2,
#  '巨': 2,
#  '全': 3,
#  '球': 2,
#  '化': 2,
#  '在': 6,
#  '个': 5,
#  '中': 3,
#  '有': 2,
#  '交': 2,
#  '换': 1,
#  '机': 9,
#  '路': 3,
#  '由': 4,
#  '器': 2,
#  '等': 2,
#  '设': 4,
#  '备': 1,
#  '各': 2,
#  '种': 3,
#  '不': 2,
#  '同': 1,
#  '接': 7,
#  '链': 1,
#  '类': 1,
#  '繁': 1,
#  '多': 3,
#  '服': 3,
#  '务': 3,
#  '和': 5,
#  '数': 2,
# ...
